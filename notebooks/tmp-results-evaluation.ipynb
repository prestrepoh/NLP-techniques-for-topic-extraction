accuracies_per_label['RoBERTa'] = {'Satisfied users': 0.9414726683599742, 'Bugs': 0.988051359420456, 'Design & UX': 0.9919472400995614, 'Dissatisfied users': 0.9763509857469332, 'Performance': 0.9950792226062932, 'Use cases': 0.995181075695943, 'Gaming': 0.9960659244122758, 'Feature Requests': 0.993946106983939, 'Complexity': 0.9964033127717409, 'Pricing': 0.9956967069622953, 'Security & Accounts': 0.9982939607483656, 'Update': 0.9960468269579665, 'Camera & Photos': 0.9985931541992119, 'Video': 0.9994016130983073, 'Customer Support': 0.9970971869449803, 'Notifications & Alerts': 0.9989687374672956, 'Frequency': 0.9980520596604473, 'Advertising': 0.9990260298302236, 'Payment': 0.9986568123802431, 'Connectivity': 0.9985740567449025, 'Devices': 0.9976892080285698, 'Audio': 0.9991151512836672, 'Sign Up & Login': 0.9986377149259337, 'Location Services': 0.9996626116405349, 'Privacy': 0.9992615651000388, 'Internationalization': 0.9996944407310505, 'no topic': 0.8828360384877053}

# %% [markdown]
# |                | Accuracy | F1 (micro) | F1 (macro) | Inference Time | Training Time        |
# |---------------------|----------|------------|------------|----------------|----------------------|
# | **Naive Bayes**         | 0.524    | 0.362      | 0.126      | 4.7 sec   | 24.7 sec      |
# | **KNN**                | 0.563    | 0.465      | 0.344      | 42 min | **20.8 sec**        |
# | **Logistic Regression** | 0.679    | 0.777      | 0.786      | **4.6 sec**  | 3 min         |
# | **SVC**                 | 0.685    | 0.788      | 0.815      | **4.6 sec**  | 1 min 56 sec         |
# | **BERT**                | 0.875    | 0.931      | **0.949**      | 35 min   | ~ 8 h per epoch  |
# | **XLNet**               | **0.878**    | 0.931      | **0.949**      | 1h 11 min   | ~ 6 h per epoch  |
# | **RoBERTa**             | **0.878**    | **0.932**      | 0.948      | 1h 5 min | ~ 10 h per epoch |

# %% [markdown]
# * DL models have pretty much the same accuracy between themselves in total (table)
# * DL models have pretty much the same accuracy between themselves per label (plot)
#
# * Total accuracy of dl models is much better than classical models (table)
#
# * Classical models perform very well for each individual category (comparable to dl models) plot
#
# * Classical models perform worse for the categories with the most datapoints
# (I can plot the accuracy of the best classical model vs the best dl model organizing the topics by number of samples, and below a histogram of the topics to show that classical models struggle to learn the distribution of the most common topics in the dataset)
#
# * Inference time of classical models much lower than dl models (table) (3 orders of magnitude)
#
# * Training time of classical models much lower than dl models (table)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (20,5))
X = np.arange(len(accuracies_per_label.get('Naive Bayes')))

#ax.bar(X, accuracies_per_label.get('Naive Bayes').values(), width=0.2, color='lightsteelblue', align='center')
#ax.bar(X-0.2, accuracies_per_label.get('KNN').values(), width=0.2, color='cornflowerblue', align='center')
#ax.bar(X-0.4, accuracies_per_label.get('Logistic Regression').values(), width=0.2, color='mediumblue', align='center')
ax.bar(X, accuracies_per_label.get('SVC').values(), width=0.2, color='blue', align='center')

ax.bar(X-0.2, accuracies_per_label.get('XLNet').values(), width=0.2, color='lightcoral', align='center',)
#ax.bar(X-1, accuracies_per_label.get('BERT').values(), width=0.2, color='firebrick', align='center')
#ax.bar(X-1.2, accuracies_per_label.get('BERT').values(), width=0.2, color='red', align='center')

#plt.xticks([i*2 for i in range(100)], accuracies_per_label.get('Naive Bayes').keys())

ax.legend(('SVC','XLNet'), loc='lower left')
plt.xticks(X, accuracies_per_label.get('Naive Bayes').keys())

for tick in ax.get_xticklabels():
    tick.set_rotation(90)
plt.title("Accuracy score", fontsize=17)
ax.set_ylabel("Accuracy", size = 12)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (20,5))
X = np.arange(len(accuracies_per_label.get('Naive Bayes')))

width = 0.1
position_delta = 0.05

ax.bar(X, accuracies_per_label.get('Naive Bayes').values(), width=width, color='lightsteelblue', align='center')
ax.bar(X-0.1, accuracies_per_label.get('KNN').values(), width=width, color='cornflowerblue', align='center')
ax.bar(X-0.2, accuracies_per_label.get('Logistic Regression').values(), width=width, color='mediumblue', align='center')
ax.bar(X-0.3, accuracies_per_label.get('SVC').values(), width=width, color='blue', align='center')

ax.bar(X-0.4, accuracies_per_label.get('XLNet').values(), width=width, color='lightcoral', align='center',)
ax.bar(X-0.5, accuracies_per_label.get('BERT').values(), width=width, color='firebrick', align='center')
ax.bar(X-0.6, accuracies_per_label.get('BERT').values(), width=width, color='red', align='center')

#plt.xticks([i*2 for i in range(100)], accuracies_per_label.get('Naive Bayes').keys())

ax.legend(('SVC','XLNet'), loc='lower left')
plt.xticks(X, accuracies_per_label.get('Naive Bayes').keys())

for tick in ax.get_xticklabels():
    tick.set_rotation(90)
plt.title("Accuracy score", fontsize=17)
ax.set_ylabel("Accuracy", size = 12)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize = (30,4))
x_position = np.arange(len(accuracies_per_label.get('Naive Bayes')))


#ax.bar(X-0.2, accuracies_per_label.get('KNN').values(), width=0.2, color='cornflowerblue', align='center')
#ax.bar(X-0.4, accuracies_per_label.get('Logistic Regression').values(), width=0.2, color='mediumblue', align='center')
#ax.bar(X, accuracies_per_label.get('SVC').values(), width=0.2, color='blue', align='center')

ax.bar(X, accuracies_per_label.get('XLNet').values(), width=0.2, color='lightcoral', align='center')
ax.bar(X, accuracies_per_label.get('SVC').values(), width=0.2, color='lightsteelblue', align='center')
#ax.bar(X-1, accuracies_per_label.get('BERT').values(), width=0.2, color='firebrick', align='center')
#ax.bar(X-1.2, accuracies_per_label.get('BERT').values(), width=0.2, color='red', align='center')

#plt.xticks([i*2 for i in range(100)], accuracies_per_label.get('Naive Bayes').values)
# Out:
# <BarContainer object of 27 artists>
